# %% [markdown]
# ## Highcharts Intro Teil 2 - Verschiende Chart Typen

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
from pygments import highlight
from pygments.lexers import PythonLexer
from pygments.lexers import HtmlLexer
from pygments.formatters import HtmlFormatter
import IPython
from IPython.display import HTML
from IPython.display import IFrame

def show_html_file(filename):
    with open(filename) as f:
        code = f.read()
    formatter = HtmlFormatter()
    iframe = IFrame(filename, width=700, height=400)
    code = HTML('<style type="text/css">{}</style>{}'.format(
        formatter.get_style_defs('.highlight'),
        highlight(code, HtmlLexer(), formatter)))
    display(iframe,code)

# %% [markdown]
# # Column Charts

# %%
show_html_file("examples/column-chart.html")
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="examples/column-chart.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# ...

# %% [markdown]
# # Line Charts
# - logarithmische Skalierung der Achsen

# %%
show_html_file("examples/line-chart.html")
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="examples/line-chart.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# ...

# %% [markdown]
# # Pie Charts (achtung böse!) aber verbieten will es nicht :)

# %%
show_html_file("examples/pie-chart.html")
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="examples/pie-chart.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# ...

# %% [markdown]
# # Scatter Plots

# %%
show_html_file("examples/scatter-chart.html")
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="examples/scatter-chart.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# ...

# %% [markdown]
# # Stacked Bar Charts

# %%
show_html_file("examples/stacked-bar-chart.html")
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="examples/stacked-bar-chart.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# ...

# %% [markdown]
# # Area Charts

# %%
show_html_file('examples/area-chart-negative-values.html')
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="examples/area-chart-negative-values.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# ...

# %% [markdown]
# # Area-Spline-Charts

# %%
show_html_file('examples/area-spline-chart.html')
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="examples/area-spline-chart.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# ...

# %% [markdown]
# # Bubble Charts

# %%
show_html_file('examples/bubble-chart.html')
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="examples/bubble-chart.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# ...

# %% [markdown]
# # Column Range Charts

# %%
show_html_file("examples/column-range-chart.html")
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="examples/column-range-chart.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# ...
